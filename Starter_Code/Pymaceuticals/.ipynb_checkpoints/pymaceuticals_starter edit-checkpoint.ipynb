# %% [markdown]
# # Pymaceuticals Inc
#
# ## Background Info:
# In this study, 249 mice who were identified with SCC tumors received treatment with a range of drug regimens. Over the course of 45 days, tumor development was observed and measured.
#
# The purpose of this study was to compare the performance of Pymaceuticals’ drug of interest, Capomulin, against the other treatment regimens.
#
# ## Drugs Tested:
# Capomulin, Ceftamin, Infubinol, Ketapril, Naftisol, Placebo, Propriva, Ramicane, Stelasyn, Zoniferol
#
# ## Analysis report:
#
# #### Summary statistics:
#     - Median for all tumor volume for all drug regimen were between the range of 40 - 54 (mm3)
#     - Ramicane was at the lowest at 40.67 mm3
#     - Capomulin was at 41.56 mm3
#     - Ketapril was at the highest at 53.70 mm3
#
# #### Bar and Pie Graphs:
#     - Capomulin and Ramicane were obsereved to have the most rows of mouse timepoint in the study
#     - Gender ratio in the study was 51% male compared to 49% females
#
# #### Quartiles, Outliers and Boxplots:
#     - Capomulin, Ceftamin, Infubinol and Ramicane were compared for their tumor volume (mm3).
#     - Capomulin and Ramicane were lower in their median tumor volume by ~10 mm3 compared to Infubinol and Ceftamin
#     - Capomulin and Ramicane distribution of tumor volume range was also lower compared to the other 2.
#       ~21 - 49 mm3 for Capomulin and Ramicane compared to 48 - 73 mm3 for Infubinol and Ceftamin.
#
# #### Correlation and Regression:
#     - Obsereved a positive correlation of 0.84 between weight (g) vs tumor volume (mm3) for mouses tested with
#       Capomulin, with a P-value <0.05
#     - Correlation linear equation represented by y = 0.95x + 21.55
#
# ##### Notes:
#     - Mouse ID G989 was removed from the study data due to duplication errors in the data.
#     - Total of 248 Mouses were analysed in this study case analysis.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np 

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata,study_results,on='Mouse ID')

# %%
# Display the data table for preview
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice
Total_mouse = len(combined_data['Mouse ID'].unique())
print(Total_mouse)
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

#Remove all uncessary columns 
check_df = combined_data[['Mouse ID','Timepoint']]

#Create a new dataframe with the duplicate data only
duplicate_df = check_df[check_df.duplicated(keep=False)]

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = combined_data.loc[combined_data['Mouse ID']=='g989']
#Display all the duplicate mouse data 
duplicate_mouse_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID
clean_data = combined_data.loc[combined_data['Mouse ID']!= 'g989']
#Display the dataframe without duplicates
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Display the total amount of mouse ID
clean_total_mouse = len(clean_data['Mouse ID'].unique())

clean_total_mouse
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

#Remove uncessary columns 
tumor_df = clean_data[['Drug Regimen','Tumor Volume (mm3)']]

#Calculates mean of tumors for each drug
drug_mean = tumor_df.groupby(by='Drug Regimen').mean(numeric_only =True)
#Renaming column
drug_mean = drug_mean.rename(columns = {'Tumor Volume (mm3)':'Mean Tumor Volume'})

#Calculates Median for tumors for each drug
drug_median = tumor_df.groupby(by='Drug Regimen').median(numeric_only =True)
#Renaming column
drug_median = drug_median.rename(columns = {'Tumor Volume (mm3)':'Median Tumor Volume'})

#Calculate variance of tumors for each drug
drug_var = tumor_df.groupby(by='Drug Regimen').var(numeric_only =True)
#Renaming colum
drug_var = drug_var.rename(columns = {'Tumor Volume (mm3)':'Tumor Volume Variance'})

#Calculate standard deviation for each drug 
drug_std = tumor_df.groupby(by='Drug Regimen').std(numeric_only =True)
#Renaming colum
drug_std = drug_std.rename(columns = {'Tumor Volume (mm3)':'Tumor Volume STD'})

#Calculate SEM of tumor volume for each drug
drug_sem = tumor_df.groupby(by='Drug Regimen').sem(numeric_only =True)
#Renaming colum
drug_sem = drug_sem.rename(columns = {'Tumor Volume (mm3)':'Tumor Volume SEM'})



# Assemble the resulting series into a single summary DataFrame.
drug_summary = pd.concat([drug_mean, drug_median, drug_var, drug_std, drug_sem],axis=1)

# %%
drug_summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume STD  Tumor Volume SEM
# Drug Regimen
# Capomulin             4.994774          0.329346
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line

#Using groupby and aggregate to retrieve the mean, median, variance, standard deviation and SEM for tumor volume for 
#each drug regimen
drug_summary_2 = tumor_df.groupby(by='Drug Regimen').agg([np.mean,np.median,np.var,np.std,st.sem])
#Display the summary table 
drug_summary_2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
#Defining x_axis points 
x_axis = np.arange(len(clean_data['Drug Regimen'].unique()))

#A list of each unique drug name
drug_list = [drug for drug in clean_data['Drug Regimen'].unique()]

#Getting y-axis values from the clean data; which is the total count for mouse ID and timepoint for each drug 
y_axis = [clean_data.loc[clean_data['Drug Regimen'] == drug ]['Mouse ID'].count() for drug in drug_list]

# %%
#Plotting bar graph
bar_plot_df = pd.DataFrame(data = {'x_axis':x_axis,'y_axis':y_axis})
bar_plot_df = bar_plot_df.sort_values('y_axis',ascending=False)
plt.bar(x_axis,bar_plot_df['y_axis'])

#Setting x axis labels using tick locations 
tick_locations = [value for value in x_axis]

#Getting drug name in order of highest counts of rows to lowest count of rows
labels = clean_data.groupby(by = 'Drug Regimen').count().sort_values('Mouse ID',ascending=False).index
plt.xticks(tick_locations,labels,rotation='vertical')

#Setting x axis and y axis labels
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse timepoints')

#Displaying the bar graph
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

#Removing uncessary columns
bar_panda = (clean_data[['Drug Regimen','Mouse ID']])

#Using pandas.plot to plot the bar graph
bar_panda.groupby(by = 'Drug Regimen').count().sort_values('Mouse ID',ascending=False).plot(kind='bar',\
                                                                                            ylabel='# of Observed Mouse timepoints',\
                                                                                           legend=False)
# Out:
# <Axes: xlabel='Drug Regimen', ylabel='# of Observed Mouse timepoints'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
clean_data.groupby('Sex')['Mouse ID'].count().plot(kind='pie',\
                                                   subplots=True,\
                                                   autopct = '%1.1f%%',\
                                                  ylabel = 'Sex',\
                                                  startangle = 180,\
                                                  colors = ['Orange','Blue'])
# Out:
# array([<Axes: ylabel='Sex'>], dtype=object)

# %%
#Generate a pie plot showing the distribution of female versus male mice using pyplot

#Defining all the values needed to use pyplot.pie 

#Creating a label list for all the unique genders in the dataframe
labels = clean_data['Sex'].unique()
#Colors to be used for the plot
colors = ['Orange','Blue']
#Creating a list for count of each gender 
sizes = clean_data.groupby('Sex')['Mouse ID'].count().values
#Explode set to zero zero to avoid cutting the graph
explode = [0,0]

#Ploting the pie graph using pyplot
plt.pie(sizes,explode=explode,labels=labels,colors=colors,\
       autopct = '%1.1f%%',\
        startangle = 180)
#Changing ylabel 
plt.ylabel('Sex')

#Displaying the pie graph 
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# A DatFrame that has the last timepoint for each mouse ID is created using groupby.
timepoint_mouse = clean_data.loc[clean_data.groupby(by='Mouse ID')['Timepoint'].idxmax()]

# The index of the DataFrame is reset. 
timepoint_mouse = timepoint_mouse.reset_index(drop=True)

# Retrieve the maximum timepoint for each mouse.
maximum_timepoint = timepoint_mouse[['Mouse ID','Timepoint']]

# %%
# The four treatment groups, Capomulin, Ramicane, Infubinol, and Ceftamin, are put in a list. (3 points)
treatment = ['Capomulin','Ramicane','Infubinol','Ceftamin']

# An empty list is created to fill with tumor volume data. (3 points)
tumor_vol_data = []

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

#Removing uncessary drugs from dataframe by isolating each drug name
df1 = clean_data.loc[clean_data['Drug Regimen']=='Capomulin']
df2 = clean_data.loc[clean_data['Drug Regimen']=='Ramicane']
df3 = clean_data.loc[clean_data['Drug Regimen']=='Infubinol']
df4 = clean_data.loc[clean_data['Drug Regimen']=='Ceftamin']

#Merge all isolated drug name dataframe into one
final_tumor = pd.concat([df1,df2,df3,df4])

# %%
# Getting the greatest timepoint for each mouse 
Mouse_id = final_tumor['Mouse ID'].unique()
last_timepoint = [final_tumor.loc[final_tumor['Mouse ID']==Mouse][['Mouse ID','Timepoint']].max() for Mouse in Mouse_id]

#Turning last_timepoint into a dataframe
greatest_timepoint = pd.DataFrame(last_timepoint)

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint for each mouse
final_tumor_vol = pd.merge(final_tumor,greatest_timepoint,on=['Mouse ID','Timepoint'],how='right')

# %%
# Display the final tumor volume dataframe for each mouse
final_tumor_vol
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      s185    Capomulin  Female           3          17         45
# 1      x401    Capomulin  Female          16          15         45
# 2      m601    Capomulin    Male          22          17         45
# 3      f966    Capomulin    Male          16          17         20
# 4      u364    Capomulin    Male          18          17         45
# ..      ...          ...     ...         ...         ...        ...
# 95     x226     Ceftamin    Male          23          28          0
# 96     x581     Ceftamin  Female          19          28         45
# 97     x822     Ceftamin    Male           3          29         45
# 98     y769     Ceftamin  Female           6          27         45
# 99     y865     Ceftamin    Male          23          26         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            23.343598                 1
# 1            28.484033                 0
# ...

# %%
# A for loop is used to display the interquartile range (IQR) and the outliers for each treatment group (10 points)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#For loop to check and print the potential outliers for each drug regimen treatment
for drug in treatment:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes 
    drug_tumor = final_tumor_vol.loc[final_tumor_vol['Drug Regimen'] == drug]
    
    #and add them to tumor_vol_data list
    tumor_vol_data.append(drug_tumor['Tumor Volume (mm3)'])
    
    #Determine outliers using upper and lower bounds
    #Defining quartiles and IQR 
    quartiles = drug_tumor['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq

    #Creating upper and lower bound for outliers 
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol['Drug Regimen'] == drug) & ((final_tumor_vol['Tumor Volume (mm3)'] < lower_bound) |\
                                  (final_tumor_vol['Tumor Volume (mm3)']> upper_bound))]
    #Printing drug name and it potential outliers with it index from final_tumor_vol
    print(f"{drug}")
    print(f"potential outliers:{outliers['Tumor Volume (mm3)']}\n")
# Out:
# Capomulin
# potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
#
# Ramicane
# potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
#
# Infubinol
# potential outliers:55    36.321346
# Name: Tumor Volume (mm3), dtype: float64
#
# Ceftamin
# potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
#Create one figure to store all the boxplots
fig1, ax1 = plt.subplots()

#Plot tumor_vol_data as a boxplot
plt.boxplot(tumor_vol_data,flierprops = dict(markerfacecolor='red'))

#Change x_axis labels to match drug name
xticks = [value +1  for value in np.arange(len(treatment))]
plt.xticks(xticks ,treatment)

#Plotting horizontal lines 
plt.grid(axis='y')
#display figure with all the boxplots
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_df = clean_data.loc[clean_data['Drug Regimen'] == 'Capomulin']

#Display all Mouse ID with Capomulin as treatment
capomulin_df['Mouse ID'].unique()
# Out:
# array(['s185', 'x401', 'm601', 'f966', 'u364', 'y793', 'r554', 'm957',
#        't565', 'i738', 'w914', 'g288', 'l897', 'b742', 'b128', 'j246',
#        'j119', 'w150', 'v923', 'g316', 's710', 'l509', 'r944', 'i557',
#        'r157'], dtype=object)

# %%
#Mouse ID s185 will be used to generate a line and scatter plot
Mouse_id = 's185'

# %%
#Remove uncessary columns 
s185_df = clean_data.loc[clean_data['Mouse ID'] == 's185'][['Timepoint', 'Tumor Volume (mm3)']]

# %%
#Defining axis 
x_axis = s185_df['Timepoint']
y_axis = s185_df['Tumor Volume (mm3)']

# %%
#plotting and setting labels
plt.plot(x_axis,y_axis)
plt.xlabel('Time Point')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin Mouse ID: s185')
plt.grid()
#Displaying line graph
plt.show()

# %%
#Remove uncessary columns
capomulin_df = capomulin_df[['Mouse ID','Weight (g)','Tumor Volume (mm3)']]

#Group dataframe by mouse ID and weight then reset the index 
capomulin_df = capomulin_df.groupby(by=['Mouse ID','Weight (g)']).mean().reset_index()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

#Define axis for scatter plot
x_axis = capomulin_df['Weight (g)']
y_axis = capomulin_df['Tumor Volume (mm3)']

#Ploting scatter 
plt.scatter(x_axis,y_axis, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)
#Setting x and y labels
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

#Giving the graph a tight layout
plt.tight_layout()
plt.grid()

#Displaying graph
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

#Defining slope, intercept, rvalue, pvalue and standard deviation
(slope, intercept, rvalue,pvalue,stdev) = st.linregress(x_axis, y_axis)

#Defining regress_value 
regress_value = x_axis * slope + intercept

#Defining line equation
line_equation = f"y = {round(slope,2)}x + {round(intercept,2)}"

#Printing line equation and correlation coefficient 
print(f"The line equation for Weight vs Tumor volume is {line_equation}")
print(f"The correlation coefficient for Weight vs Tumor volume is {round(rvalue,2)}")
# Out:
# The line equation for Weight vs Tumor volume is y = 0.95x + 21.55
# The correlation coefficient for Weight vs Tumor volume is 0.84

# %%
#Replotting the scatter plot 
plt.scatter(x_axis,y_axis, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
#Adding in the linear equation to the graph
plt.plot(x_axis,regress_value,"--",label= line_equation)
#Adding linear equation label to the graph
plt.annotate(line_equation, (18,37),fontsize= 15,color='blue')
#Tight layout and displaying the final graph
plt.tight_layout()
plt.grid()
#Displaying graph
plt.show()
